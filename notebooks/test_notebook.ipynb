# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
read_dir = os.path.join(os.path.expanduser("~"), "Desktop","projects","gee-pull", "data","training")
file_name = "G081060E29919N_201110274_Landsat5.tif"

# %%
with rasterio.open(os.path.join(read_dir,file_name)) as src:
    img = src.read()
    img = np.rollaxis(img,0,3)
plt.imshow(img[:,:,0:3])
